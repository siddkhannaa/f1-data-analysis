# %%
import fastf1 as ff1
from fastf1 import plotting
from fastf1 import utils

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import numpy as np
import pandas as pd

ff1.plotting.setup_mpl(misc_mpl_mods=False)

# %%
# as of shanghai race session
session = ff1.get_session(2024, 5, 'R')
session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (109.64 MB) C:\Users\fedor\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.3.5]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Cannot load lap times for first lap from Ergast. Timing data is not available for this session.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# ...

# %%
for driver in session.drivers:
    print(f"{session.get_driver(driver)['ClassifiedPosition']} {session.get_driver(driver)['FullName']} ({session.get_driver(driver)['TeamName']})")
# Out:
# 1 Max Verstappen (Red Bull Racing)
# 2 Lando Norris (McLaren)
# 3 Sergio Perez (Red Bull Racing)
# 4 Charles Leclerc (Ferrari)
# 5 Carlos Sainz (Ferrari)
# 6 George Russell (Mercedes)
# 7 Fernando Alonso (Aston Martin)
# 8 Oscar Piastri (McLaren)
# 9 Lewis Hamilton (Mercedes)
# 10 Nico Hulkenberg (Haas F1 Team)
# 11 Esteban Ocon (Alpine)
# 12 Alexander Albon (Williams)
# 13 Pierre Gasly (Alpine)
# 14 Guanyu Zhou (Kick Sauber)
# 15 Lance Stroll (Aston Martin)
# 16 Kevin Magnussen (Haas F1 Team)
# 17 Logan Sargeant (Williams)
# R Daniel Ricciardo (RB)
# R Yuki Tsunoda (RB)
# R Valtteri Bottas (Kick Sauber)

# %%
for driver in session.drivers:
    print(session.get_driver(driver))
# Out:
# DriverNumber                                                          1
# BroadcastName                                              M VERSTAPPEN
# Abbreviation                                                        VER
# DriverId                                                 max_verstappen
# TeamName                                                Red Bull Racing
# TeamColor                                                        3671C6
# TeamId                                                         red_bull
# FirstName                                                           Max
# LastName                                                     Verstappen
# FullName                                                 Max Verstappen
# HeadshotUrl           https://media.formula1.com/d_driver_fallback_i...
# CountryCode                                                         NED
# Position                                                            1.0
# ...
